# %%
import circle_fit as cf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_circles

def get_unit_circle():
    data = make_circles(noise=.1, factor=.05)
    idx = np.argwhere(data[1]==0)
    x = data[0][idx, 0]
    y = data[0][idx, 1]
    return x, y

x, y = get_unit_circle()
plt.scatter(x, y)

# %%
coords = [[x[i][0], y[i][0]] for i in range(len(x))]
coords[0]
# Out:
# [0.5816871398290294, -0.8743850100230013]

# %%
xc,yc,r,s = cf.hyper_fit(coords)

# %%
cf.plot_data_circle(x,y,xc,yc,r)

# %%
xc, yc, r, s = cf.least_squares_circle(coords)

# %%
cf.plot_data_circle(x,y,xc,yc,r)
